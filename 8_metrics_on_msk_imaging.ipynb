# %%
# this notebook calculates performance metrics on external MSK imaging test data
# (MSK ran the DFCI-student-imaging model on its own data, then shared deidentified outputs for evaluation)

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils import data
from transformers import AutoTokenizer
from torch.utils.data import DataLoader

# %%
output_dataset = pd.read_csv('/mnt/d/Dropbox (Partners HealthCare)/dfci_mimic_imaging_bert/msk_imaging_data/msk_predictions_radiology_noPHI.csv')

# %%
output_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24472 entries, 0 to 24471
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DMP_ID               24472 non-null  object
#  1   cancer_type          24472 non-null  object
#  2   any_cancer_label     24472 non-null  bool
#  3   response_label       24472 non-null  bool
#  4   progression_label    24472 non-null  bool
#  5   Bone                 24472 non-null  int64
#  6   CNS_Brain            24472 non-null  int64
#  7   Intra-Abdominal      24472 non-null  int64
#  8   Liver                24472 non-null  int64
#  9   Lung                 24472 non-null  int64
#  10  Other                24472 non-null  int64
#  11  Pleura               24472 non-null  int64
#  12  Reproductive_Organs  24472 non-null  int64
#  13  adrenal_glands       24472 non-null  int64
#  14  lymph_nodes          24472 non-null  int64
#  15  prob_any_cancer      24472 non-null  float64
#  16  prob_response        24472 non-null  float64
#  17  prob_progression     24472 non-null  float64
#  18  prob_brain           24472 non-null  float64
#  19  prob_bone            24472 non-null  float64
#  20  prob_adrenal         24472 non-null  float64
#  21  prob_liver           24472 non-null  float64
#  22  prob_lung            24472 non-null  float64
#  23  prob_node            24472 non-null  float64
#  24  prob_peritoneum      24472 non-null  float64
# dtypes: bool(3), float64(10), int64(10), object(2)
# memory usage: 4.2+ MB

# %%
output_dataset = output_dataset.rename(columns={'any_cancer_label':'any_cancer', 'response_label':'response', 'progression_label':'progression',
                                  'Bone':'bone_met', 'CNS_Brain':'brain_met', 'Intra-Abdominal':'peritoneal_met', 'Liver':'liver_met',
                                 'Lung':'lung_met', 'adrenal_glands':'adrenal_met', 'lymph_nodes':'node_met', 'prob_lung':'prob_lung_met',
                                               'prob_brain':'prob_brain_met','prob_bone':'prob_bone_met','prob_adrenal':'prob_adrenal_met',
                                               'prob_liver':'prob_liver_met','prob_node':'prob_node_met','prob_peritoneum':'prob_peritoneal_met'})

# %%
#output_dataset

# %%
from utils_102023 import eval_model

# %%
for outcome in ['any_cancer','progression','response','brain_met','bone_met','adrenal_met','liver_met','lung_met','node_met','peritoneal_met']:
    print('all cancers')
    print(outcome)
    print(eval_model(output_dataset['prob_' + outcome], output_dataset[outcome], graph=False))
    print("\n")
# Out:
# all cancers
# any_cancer
# AUC 0.9872538656321208
# Outcome probability: 0.7824043805165086
# Average precision score: 1.00
# Best F1: 0.9721997441854395
# Best F1 threshold: 0.2352055013179779
# 0.2352055013179779
#
#
# all cancers
# progression
# AUC 0.9704799735551629
# Outcome probability: 0.3877492644655116
# Average precision score: 0.96
# Best F1: 0.8912105618795156
# Best F1 threshold: 0.3986702859401703
# 0.3986702859401703
#
#
# all cancers
# response
# AUC 0.9738039935985858
# Outcome probability: 0.12732919254658384
# Average precision score: 0.88
# Best F1: 0.8054941585096305
# Best F1 threshold: 0.4937248826026916
# 0.4937248826026916
#
#
# all cancers
# brain_met
# AUC 0.9892708938752353
# Outcome probability: 0.015691402419091206
# Average precision score: 0.83
# Best F1: 0.7872078720787208
# Best F1 threshold: 0.1955713033676147
# 0.1955713033676147
#
#
# all cancers
# bone_met
# AUC 0.9912585432486332
# Outcome probability: 0.25257437070938216
# Average precision score: 0.98
# Best F1: 0.9331122166943062
# Best F1 threshold: 0.3544026911258697
# 0.3544026911258697
#
#
# all cancers
# adrenal_met
# AUC 0.9953904977483952
# Outcome probability: 0.02517162471395881
# Average precision score: 0.92
# Best F1: 0.8913385826771654
# Best F1 threshold: 0.5595877170562744
# 0.5595877170562744
#
#
# all cancers
# liver_met
# AUC 0.991047348699515
# Outcome probability: 0.30790290944753185
# Average precision score: 0.98
# Best F1: 0.9433067755317047
# Best F1 threshold: 0.4431492686271667
# 0.4431492686271667
#
#
# all cancers
# lung_met
# AUC 0.9789528105964191
# Outcome probability: 0.24701699901928734
# Average precision score: 0.94
# Best F1: 0.888870928634931
# Best F1 threshold: 0.369525671005249
# 0.369525671005249
#
#
# all cancers
# node_met
# AUC 0.9603821119683592
# Outcome probability: 0.2528604118993135
# Average precision score: 0.86
# Best F1: 0.8316889146836912
# Best F1 threshold: 0.3314014971256256
# 0.3314014971256256
#
#
# all cancers
# peritoneal_met
# AUC 0.9671870072940788
# Outcome probability: 0.09390323635174894
# Average precision score: 0.87
# Best F1: 0.8205009276437848
# Best F1 threshold: 0.4702681303024292
# 0.4702681303024292

# %%
for cancer in output_dataset.cancer_type.unique():
    subset = output_dataset[output_dataset.cancer_type == cancer]
    for outcome in ['any_cancer','progression','response','brain_met','bone_met','adrenal_met','liver_met','lung_met','node_met','peritoneal_met']:
        print(cancer)
        print(outcome)
        print(eval_model(subset['prob_' + outcome], subset[outcome], graph=False))
        print("\n")
# Out:
# brca
# any_cancer
# AUC 0.9865254799540846
# Outcome probability: 0.8551816958277254
# Average precision score: 1.00
# Best F1: 0.9768025078369905
# Best F1 threshold: 0.1746265441179275
# 0.1746265441179275
#
#
# brca
# progression
# AUC 0.9602610362535804
# Outcome probability: 0.41938088829071335
# Average precision score: 0.95
# Best F1: 0.8807631160572338
# Best F1 threshold: 0.4114409685134887
# 0.4114409685134887
#
#
# brca
# response
# AUC 0.960192271178574
# Outcome probability: 0.12570659488559893
# Average precision score: 0.77
# Best F1: 0.7344064386317909
# Best F1 threshold: 0.4896712899208069
# 0.4896712899208069
#
#
# brca
# brain_met
# AUC 0.9821990737927094
# Outcome probability: 0.03714670255720054
# Average precision score: 0.86
# Best F1: 0.7999999999999999
# Best F1 threshold: 0.1877919435501098
# 0.1877919435501098
#
#
# brca
# bone_met
# AUC 0.9798061968361857
# Outcome probability: 0.5580080753701211
# Average precision score: 0.98
# Best F1: 0.9373232799245993
# Best F1 threshold: 0.3166042268276214
# 0.3166042268276214
#
#
# brca
# adrenal_met
# AUC 0.9986224314085639
# Outcome probability: 0.016689098250336473
# Average precision score: 0.94
# Best F1: 0.9032258064516129
# Best F1 threshold: 0.5616635680198669
# 0.5616635680198669
#
#
# brca
# liver_met
# AUC 0.9913537145673359
# Outcome probability: 0.351278600269179
# Average precision score: 0.98
# Best F1: 0.9495638983693592
# Best F1 threshold: 0.3687283396720886
# 0.3687283396720886
#
#
# brca
# lung_met
# AUC 0.9689403462297738
# Outcome probability: 0.16446837146702556
# Average precision score: 0.88
# Best F1: 0.8306709265175718
# Best F1 threshold: 0.4294106662273407
# 0.4294106662273407
#
#
# brca
# node_met
# AUC 0.9768680571748435
# Outcome probability: 0.31467025572005386
# Average precision score: 0.94
# Best F1: 0.8952380952380953
# Best F1 threshold: 0.215519443154335
# 0.215519443154335
#
#
# brca
# peritoneal_met
# AUC 0.9695823778750607
# Outcome probability: 0.05518169582772544
# Average precision score: 0.85
# Best F1: 0.8217054263565892
# Best F1 threshold: 0.3300366401672363
# 0.3300366401672363
#
#
# crc
# any_cancer
# AUC 0.9901751938303767
# Outcome probability: 0.7617206379893668
# Average precision score: 1.00
# Best F1: 0.9747205284552845
# Best F1 threshold: 0.2352055013179779
# 0.2352055013179779
#
#
# crc
# progression
# AUC 0.9788200655828989
# Outcome probability: 0.4028999516674722
# Average precision score: 0.97
# Best F1: 0.9133301931229393
# Best F1 threshold: 0.4061508178710937
# 0.4061508178710937
#
#
# crc
# response
# AUC 0.9816239581105248
# Outcome probability: 0.13987433542774286
# Average precision score: 0.92
# Best F1: 0.8559266535690897
# Best F1 threshold: 0.2999919950962066
# 0.2999919950962066
#
#
# crc
# brain_met
# AUC 0.9900691530881062
# Outcome probability: 0.009279845335911068
# Average precision score: 0.85
# Best F1: 0.7724867724867724
# Best F1 threshold: 0.2702471613883972
# 0.2702471613883972
#
#
# crc
# bone_met
# AUC 0.9894449193151501
# Outcome probability: 0.07317544707588207
# Average precision score: 0.94
# Best F1: 0.8877551020408163
# Best F1 threshold: 0.5464271306991577
# 0.5464271306991577
#
#
# crc
# adrenal_met
# AUC 0.9959902745318259
# Outcome probability: 0.02793620106331561
# Average precision score: 0.95
# Best F1: 0.9238578680203046
# Best F1 threshold: 0.6264373064041138
# 0.6264373064041138
#
#
# crc
# liver_met
# AUC 0.9853226451684186
# Outcome probability: 0.43112614789753506
# Average precision score: 0.98
# Best F1: 0.9431184474682133
# Best F1 threshold: 0.4172287583351135
# 0.4172287583351135
#
#
# crc
# lung_met
# AUC 0.9805486242879548
# Outcome probability: 0.3457709038182697
# Average precision score: 0.96
# Best F1: 0.917262231995602
# Best F1 threshold: 0.3725149631500244
# 0.3725149631500244
#
#
# crc
# node_met
# AUC 0.9565926830822659
# Outcome probability: 0.23663605606573224
# Average precision score: 0.83
# Best F1: 0.8173178458289334
# Best F1 threshold: 0.2233402729034423
# 0.2233402729034423
#
#
# crc
# peritoneal_met
# AUC 0.9684694693663727
# Outcome probability: 0.13610439826002899
# Average precision score: 0.89
# Best F1: 0.8341744772891132
# Best F1 threshold: 0.321799486875534
# 0.321799486875534
#
#
# prostate
# any_cancer
# AUC 0.976668241286533
# Outcome probability: 0.8376257545271629
# Average precision score: 1.00
# Best F1: 0.9690254944007624
# Best F1 threshold: 0.1937326788902282
# 0.1937326788902282
#
#
# prostate
# progression
# AUC 0.9526353021116598
# Outcome probability: 0.37746478873239436
# Average precision score: 0.93
# Best F1: 0.8533400301356102
# Best F1 threshold: 0.2740959227085113
# 0.2740959227085113
#
#
# prostate
# response
# AUC 0.9616306983253763
# Outcome probability: 0.11408450704225352
# Average precision score: 0.79
# Best F1: 0.7300613496932515
# Best F1 threshold: 0.3158023655414581
# 0.3158023655414581
#
#
# prostate
# brain_met
# AUC 0.988964620459742
# Outcome probability: 0.018913480885311872
# Average precision score: 0.77
# Best F1: 0.7999999999999999
# Best F1 threshold: 0.2260856479406356
# 0.2260856479406356
#
#
# prostate
# bone_met
# AUC 0.9849407225755092
# Outcome probability: 0.5867203219315895
# Average precision score: 0.99
# Best F1: 0.9564925247774231
# Best F1 threshold: 0.2333549410104751
# 0.2333549410104751
#
#
# prostate
# adrenal_met
# AUC 0.9979169252730884
# Outcome probability: 0.021327967806841045
# Average precision score: 0.90
# Best F1: 0.8928571428571428
# Best F1 threshold: 0.6504672765731812
# 0.6504672765731812
#
#
# prostate
# liver_met
# AUC 0.9991791150270527
# Outcome probability: 0.0806841046277666
# Average precision score: 0.99
# Best F1: 0.9606879606879607
# Best F1 threshold: 0.704332172870636
# 0.704332172870636
#
#
# prostate
# lung_met
# AUC 0.9782436036380637
# Outcome probability: 0.10181086519114688
# Average precision score: 0.89
# Best F1: 0.8338308457711443
# Best F1 threshold: 0.5675205588340759
# 0.5675205588340759
#
#
# prostate
# node_met
# AUC 0.955356370744689
# Outcome probability: 0.3665995975855131
# Average precision score: 0.90
# Best F1: 0.8725198412698412
# Best F1 threshold: 0.187957152724266
# 0.187957152724266
#
#
# prostate
# peritoneal_met
# AUC 0.9640518658460991
# Outcome probability: 0.019517102615694164
# Average precision score: 0.74
# Best F1: 0.7868852459016393
# Best F1 threshold: 0.4453416764736175
# 0.4453416764736175
#
#
# nsclc
# any_cancer
# AUC 0.9803126088455202
# Outcome probability: 0.6493589743589744
# Average precision score: 0.99
# Best F1: 0.9512670565302145
# Best F1 threshold: 0.155813381075859
# 0.155813381075859
#
#
# nsclc
# progression
# AUC 0.9698389217619987
# Outcome probability: 0.3
# Average precision score: 0.94
# Best F1: 0.8751311647429172
# Best F1 threshold: 0.3796362578868866
# 0.3796362578868866
#
#
# nsclc
# response
# AUC 0.9719797039901787
# Outcome probability: 0.08525641025641026
# Average precision score: 0.84
# Best F1: 0.7709090909090909
# Best F1 threshold: 0.4581231474876404
# 0.4581231474876404
#
#
# nsclc
# brain_met
# AUC 0.9903699401666689
# Outcome probability: 0.03141025641025641
# Average precision score: 0.80
# Best F1: 0.8148148148148148
# Best F1 threshold: 0.2891540229320526
# 0.2891540229320526
#
#
# nsclc
# bone_met
# AUC 0.988277800080289
# Outcome probability: 0.15064102564102563
# Average precision score: 0.93
# Best F1: 0.8742268041237113
# Best F1 threshold: 0.4542329013347626
# 0.4542329013347626
#
#
# nsclc
# adrenal_met
# AUC 0.9970298621818217
# Outcome probability: 0.04551282051282051
# Average precision score: 0.92
# Best F1: 0.9139072847682119
# Best F1 threshold: 0.577853262424469
# 0.577853262424469
#
#
# nsclc
# liver_met
# AUC 0.9933926634092226
# Outcome probability: 0.0532051282051282
# Average precision score: 0.94
# Best F1: 0.9005847953216374
# Best F1 threshold: 0.3959583938121795
# 0.3959583938121795
#
#
# nsclc
# lung_met
# AUC 0.9503264425139426
# Outcome probability: 0.4307692307692308
# Average precision score: 0.94
# Best F1: 0.8593974175035869
# Best F1 threshold: 0.1652445644140243
# 0.1652445644140243
#
#
# nsclc
# node_met
# AUC 0.9675294688871355
# Outcome probability: 0.19294871794871796
# Average precision score: 0.87
# Best F1: 0.8247422680412371
# Best F1 threshold: 0.2201360017061233
# 0.2201360017061233
#
#
# nsclc
# peritoneal_met
# AUC 0.9568241912299693
# Outcome probability: 0.023717948717948717
# Average precision score: 0.79
# Best F1: 0.8181818181818181
# Best F1 threshold: 0.4991995394229889
# 0.4991995394229889
#
#
# pancreas
# any_cancer
# AUC 0.9912973561660154
# Outcome probability: 0.7506439979392066
# Average precision score: 1.00
# Best F1: 0.9756432246998284
# Best F1 threshold: 0.2604956030845642
# 0.2604956030845642
#
#
# pancreas
# progression
# AUC 0.9756752294780224
# Outcome probability: 0.3655332302936631
# Average precision score: 0.96
# Best F1: 0.9028213166144201
# Best F1 threshold: 0.3668601512908935
# 0.3668601512908935
#
#
# pancreas
# response
# AUC 0.9742597656710437
# Outcome probability: 0.1293147861926842
# Average precision score: 0.91
# Best F1: 0.8591408591408592
# Best F1 threshold: 0.5642004013061523
# 0.5642004013061523
#
#
# pancreas
# brain_met
# AUC 0.9998156682027649
# Outcome probability: 0.0018031942297784646
# Average precision score: 0.90
# Best F1: 0.8750000000000001
# Best F1 threshold: 0.2362103015184402
# 0.2362103015184402
#
#
# pancreas
# bone_met
# AUC 0.9970722433460076
# Outcome probability: 0.05151983513652756
# Average precision score: 0.96
# Best F1: 0.8990384615384616
# Best F1 threshold: 0.3393934369087219
# 0.3393934369087219
#
#
# pancreas
# adrenal_met
# AUC 0.9845539607993482
# Outcome probability: 0.02266872746007213
# Average precision score: 0.80
# Best F1: 0.7810650887573963
# Best F1 threshold: 0.5751960873603821
# 0.5751960873603821
#
#
# pancreas
# liver_met
# AUC 0.9928775457876335
# Outcome probability: 0.33127253992787226
# Average precision score: 0.99
# Best F1: 0.9469638739431206
# Best F1 threshold: 0.4977764189243316
# 0.4977764189243316
#
#
# pancreas
# lung_met
# AUC 0.980544289066261
# Outcome probability: 0.1749098402885111
# Average precision score: 0.94
# Best F1: 0.889367816091954
# Best F1 threshold: 0.4268020689487457
# 0.4268020689487457
#
#
# pancreas
# node_met
# AUC 0.9560344558615524
# Outcome probability: 0.11540443070582174
# Average precision score: 0.69
# Best F1: 0.6958211856171039
# Best F1 threshold: 0.634552001953125
# 0.634552001953125
#
#
# pancreas
# peritoneal_met
# AUC 0.942852192542039
# Outcome probability: 0.14193714580113342
# Average precision score: 0.86
# Best F1: 0.8057259713701431
# Best F1 threshold: 0.6734594106674194
# 0.6734594106674194
